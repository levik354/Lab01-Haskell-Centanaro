-- %%
doble :: Int -> Int
doble n = n*2
doble 4
doble 123
-- Out:
-- 8
-- 246

-- %%
esMayorEdad :: Int -> Bool
esMayorEdad n = n>= 18
esMayorEdad 21
esMayorEdad 18
esMayorEdad 15
-- Out:
-- True
-- True
-- False

-- %%
areaCirculo :: Float -> Float
areaCirculo r = pi * (r**2)
areaCirculo 4.3 
areaCirculo 6
areaCirculo 12
-- Out:
-- 58.088055
-- 113.097336
-- 452.38934
